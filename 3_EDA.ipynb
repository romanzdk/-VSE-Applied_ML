# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"./data/2_data_sample.csv")

# %%
df
# Out:
#        Unnamed: 0             Hráč                   Oddíl  \
# 0               0    Tomáš Tregler        HB Ostrov , z.s.
# 1               1    Tomáš Tregler   TT Club Ostrava, z.s.
# 2               2    Tomáš Tregler        HB Ostrov , z.s.
# 3               3  David Reitšpies               SKST Cheb
# 4               4  David Reitšpies               SKST Cheb
# ...           ...              ...                     ...
# 59057       59057   Martin Novotný            DDM Soběslav
# 59058       59058   Martin Novotný            DDM Soběslav
# 59059       59059   Martin Novotný            DDM Soběslav
# 59060       59060   Martin Novotný            DDM Soběslav
# 59061       59061   Martin Novotný            DDM Soběslav
#
#                         Družstvo                Soupeř  \
# 0               HB Ostrov H.Brod  Oleksandr Tymofieiev
# 1               TTC Ostrava 2016     Michal Lebeda ml.
# 2       STEN marketing HB Ostrov          Peter Šereda
# 3                      SKST Cheb             Jan Pisár
# 4                      SKST Cheb        Martin Olejník
# ...                          ...                   ...
# 59057             DDM Soběslav C         Martin Vlášek
# 59058             DDM Soběslav A         Jiří Strouhal
# 59059             DDM Soběslav D        Martin Šuhájek
# 59060             DDM Soběslav D        Vojtěch Havlík
# 59061             DDM Soběslav C            Jan Smolík
#
#                                       Oddíl soupeř  \
# 0                                SKST Hodonín z.s.
# 1                     TJ Sokol PP Hradec Králové 2
# 2                               DTJ Hradec Králové
# 3       Stavební fakulta SK Kotlářka El Niňo Praha
# 4                    Klub stolního tenisu KT Praha
# ...                                            ...
# 59057                            TJ VS Tábor, z.s.
# 59058                            TJ VS Tábor, z.s.
# 59059                       TJ Nová Včelnice, z.s.
# 59060                    Katolický dům Dačice z.s.
# 59061    Tělocvičná jednota Sokol Kardašova Řečice
#
#                                  Družstvo soupeř Výsledek   Datum zápasu  \
# 0                              SKST PLUS Hodonín     3:0      1.10.2021
# 1       TJ Sokol PP Hradec Králové 2 Lunatour.cz     3:0       2.4.2017
# 2                             DTJ Hradec Králové     3:0      13.5.2015
# 3                         SF SKK El Niňo Praha B     3:0      4.12.2021
# 4                                       KT Praha     3:0      24.9.2021
# ...                                          ...      ...            ...
# 59057                    TJ Vodní stavby Tábor D     3:2     11.11.2015
# 59058                                 VS Tábor A     1:3       2.2.2015
# 59059                         TJ Nová Včelnice A     3:1      25.1.2014
# 59060                             ST KD Dačice A     1:3      23.1.2014
# 59061                     OST Kardašova Řečice A     1:3      12.1.2013
#
#                          Soutěž  ...    Elo (max)  Elo soupeře  \
# 0                Extraliga mužů  ...  2473-> 2473  2167-> 2167
# 1                Extraliga mužů  ...  2411-> 2411  2079-> 2079
# 2                Extraliga mužů  ...  2427-> 2430  2330-> 2326
# 3       Český pohár II.st. muži  ...  2486-> 2486  2047-> 2047
# 4                Extraliga mužů  ...  2447-> 2453  2345-> 2342
# ...                         ...  ...          ...          ...
# 59057         Regionální přebor  ...  1413-> 1415  1261-> 1259
# 59058                    Divize  ...  1425-> 1425  1657-> 1657
# 59059  Krajská soutěž skupina C  ...  1420-> 1427  1453-> 1446
# 59060  Krajská soutěž skupina C  ...  1426-> 1421  1468-> 1472
# 59061  Krajská soutěž skupina C  ...  1426-> 1423  1539-> 1540
#
#       Elo (min) soupeře Elo (max) soupeře Rok narození Max elo  \
# 0           2143-> 2143       2200-> 2200         1990  2458.0
# 1           2060-> 2060       2100-> 2100         1990  2458.0
# 2           2308-> 2305       2347-> 2343         1990  2458.0
# 3           2035-> 2035       2059-> 2059         1996  2419.0
# 4           2326-> 2323       2361-> 2357         1996  2419.0
# ...                 ...               ...          ...     ...
# 59057       1249-> 1247       1268-> 1266         1958  1446.0
# 59058       1647-> 1647       1667-> 1667         1958  1446.0
# 59059       1444-> 1438       1464-> 1457         1958  1446.0
# 59060       1454-> 1458       1485-> 1489         1958  1446.0
# 59061       1522-> 1524       1551-> 1552         1958  1446.0
#
#        Elo nejlepšího poraženého soupeře                        ID Hráč  \
# 0                                 2446.0    /st/hrac/tregler_tomas_1990
# 1                                 2446.0    /st/hrac/tregler_tomas_1990
# 2                                 2446.0    /st/hrac/tregler_tomas_1990
# 3                                 2458.0  /st/hrac/reitspies_david_1996
# 4                                 2458.0  /st/hrac/reitspies_david_1996
# ...                                  ...                            ...
# 59057                             1567.0   /st/hrac/novotny_martin_1958
# 59058                             1567.0   /st/hrac/novotny_martin_1958
# 59059                             1567.0   /st/hrac/novotny_martin_1958
# 59060                             1567.0   /st/hrac/novotny_martin_1958
# 59061                             1567.0   /st/hrac/novotny_martin_1958
#
#                        ID Soupeř Rok narození soupeř
# 0      tymofieiev_oleksandr_1996                1996
# 1          lebeda_michal_ml_1993                1993
# 2              sereda_peter_1984                1984
# 3                 pisar_jan_2004                2004
# 4            olejnik_martin_1972                1972
# ...                          ...                 ...
# 59057         vlasek_martin_1973                1973
# 59058         strouhal_jiri_1991                1991
# 59059        suhajek_martin_1975                1975
# 59060        havlik_vojtech_1994                1994
# 59061            smolik_jan_1996                1996
#
# [59062 rows x 22 columns]

# %% [markdown]
# # Basic description

# %%
df.shape
# Out:
# (59062, 22)

# %%
df.describe()
# Out:
#          Unnamed: 0  Rok narození       Max elo  \
# count  59062.000000  59062.000000  59031.000000
# mean   29530.500000   1974.988419   1460.981213
# std    17049.875136     20.049796    251.330401
# min        0.000000   1073.000000    116.000000
# 25%    14765.250000   1963.000000   1304.000000
# 50%    29530.500000   1974.000000   1465.000000
# 75%    44295.750000   1987.000000   1625.000000
# max    59061.000000   2012.000000   2458.000000
#
#        Elo nejlepšího poraženého soupeře  Rok narození soupeř
# count                       59033.000000         59062.000000
# mean                         1609.757373          1975.099658
# std                           227.648861            20.283874
# min                           173.000000          1073.000000
# 25%                          1469.000000          1963.000000
# 50%                          1609.000000          1974.000000
# 75%                          1754.000000          1989.000000
# max                          2458.000000          2013.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59062 entries, 0 to 59061
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         59062 non-null  int64
#  1   Hráč                               59062 non-null  object
#  2   Oddíl                              59062 non-null  object
#  3   Družstvo                           59062 non-null  object
#  4   Soupeř                             59062 non-null  object
#  5   Oddíl soupeř                       59062 non-null  object
#  6   Družstvo soupeř                    59062 non-null  object
#  7   Výsledek                           59062 non-null  object
#  8   Datum zápasu                       59062 non-null  object
#  9   Soutěž                             59062 non-null  object
#  10  Elo hráče                          59062 non-null  object
#  11  Elo (min)                          59062 non-null  object
#  12  Elo (max)                          59062 non-null  object
#  13  Elo soupeře                        59062 non-null  object
#  14  Elo (min) soupeře                  59062 non-null  object
#  15  Elo (max) soupeře                  59062 non-null  object
#  16  Rok narození                       59062 non-null  int64
#  17  Max elo                            59031 non-null  float64
#  18  Elo nejlepšího poraženého soupeře  59033 non-null  float64
#  19  ID Hráč                            59062 non-null  object
#  20  ID Soupeř                          59062 non-null  object
#  21  Rok narození soupeř                59062 non-null  int64
# dtypes: float64(2), int64(3), object(17)
# memory usage: 9.9+ MB

# %%
df.isna().sum()
# Out:
# Unnamed: 0                            0
# Hráč                                  0
# Oddíl                                 0
# Družstvo                              0
# Soupeř                                0
# Oddíl soupeř                          0
# Družstvo soupeř                       0
# Výsledek                              0
# Datum zápasu                          0
# Soutěž                                0
# Elo hráče                             0
# Elo (min)                             0
# Elo (max)                             0
# Elo soupeře                           0
# Elo (min) soupeře                     0
# Elo (max) soupeře                     0
# Rok narození                          0
# Max elo                              31
# Elo nejlepšího poraženého soupeře    29
# ID Hráč                               0
# ID Soupeř                             0
# Rok narození soupeř                   0
# dtype: int64

# %% [markdown]
# # Divide variables into categorical and numerical

# %%
[df.columns]
# Out:
# [Index(['Unnamed: 0', 'Hráč', 'Oddíl', 'Družstvo', 'Soupeř', 'Oddíl soupeř',
#         'Družstvo soupeř', 'Výsledek', 'Datum zápasu', 'Soutěž', 'Elo hráče',
#         'Elo (min)', 'Elo (max)', 'Elo soupeře', 'Elo (min) soupeře',
#         'Elo (max) soupeře', 'Rok narození', 'Max elo',
#         'Elo nejlepšího poraženého soupeře', 'ID Hráč', 'ID Soupeř',
#         'Rok narození soupeř'],
#        dtype='object')]

# %%
# define categorical and numerical columns
cat_c = df.columns
num_c = []

# %% [markdown]
# # Value counts for categorical variables

# %%
for c in cat_c:
    try:
        print(f"{30*'-'}")
        print("Column:", str(c))
        print(df[c].value_counts()[:5])
        print("Unique values:", df[c].nunique())
        print()
    except:
        pass
# Out:
# ------------------------------
# Column: Unnamed: 0
# 0        1
# 39365    1
# 39367    1
# 39368    1
# 39369    1
# Name: Unnamed: 0, dtype: int64
# Unique values: 59062
#
# ------------------------------
# Column: Hráč
# Petr Novotný     49
# Pavel Novotný    37
# Petr Novák       37
# Josef Němec      28
# Jiří Bartoš      27
# Name: Hráč, dtype: int64
# Unique values: 12162
#
# ------------------------------
# Column: Oddíl
#  Stavební fakulta SK Kotlářka El Niňo Praha      265
#  Sportovní klub stolního tenisu Liberec, z.s.    249
#  TTC ELIZZA PRAHA, z.s.                          229
#  AC Sparta Praha - stolní tenis, z.s.            205
#  Klub stolního tenisu Bohnice z.s.               202
# Name: Oddíl, dtype: int64
# Unique values: 1387
#
# ------------------------------
# Column: Družstvo
#  TJ Sokol Nový Malín         43
#  TJ Zelená Liška A           43
#  TJ Lokomotiva Vršovice B    41
#  TJ Sokol Nusle Praha C      40
#  TJ Sokol Starý Plzenec A    39
# Name: Družstvo, dtype: int64
# Unique values: 8158
#
# ------------------------------
# Column: Soupeř
# Pavel Novotný    48
# Petr Novotný     40
# Milan Staněk     33
# Aleš Novák       32
# Petr Novák       29
# Name: Soupeř, dtype: int64
# Unique values: 18442
#
# ------------------------------
# Column: Oddíl soupeř
#  Sportovní klub stolního tenisu Liberec, z.s.    297
#  Stavební fakulta SK Kotlářka El Niňo Praha      257
#  TTC ELIZZA PRAHA, z.s.                          253
#  Klub stolního tenisu Bohnice z.s.               239
#  AC Sparta Praha - stolní tenis, z.s.            235
# Name: Oddíl soupeř, dtype: int64
# Unique values: 1420
#
# ------------------------------
# Column: Družstvo soupeř
#  TJ Zelená Liška A       41
#  TJ Sokol Loučka B       39
#  TJ Sokol Vranovice A    38
#  TJ Jičín B              37
#  TJ Sokol Plzeň V. C     36
# Name: Družstvo soupeř, dtype: int64
# Unique values: 8536
#
# ------------------------------
# Column: Výsledek
# 3:0     14262
# 0:3     12270
# 3:1      9972
# 1:3      9159
# 3:2      6731
# Name: Výsledek, dtype: int64
# Unique values: 7
#
# ------------------------------
# Column: Datum zápasu
#   7.12.2019      166
#   26.10.2019     166
#   22.2.2020      163
#   25.2.2017      161
#   30.10.2021     160
# Name: Datum zápasu, dtype: int64
# Unique values: 2144
#
# ------------------------------
# Column: Soutěž
# Okresní přebor             1534
# Okresní přebor 1. třídy    1268
# Regionální přebor          1176
# Divize                     1070
# Okresní přebor 2. třídy     966
# Name: Soutěž, dtype: int64
# Unique values: 1035
#
# ------------------------------
# Column: Elo hráče
# 1-> 1          159
# 1259-> 1259     28
# 1154-> 1154     27
# 1309-> 1309     26
# 1440-> 1440     26
# Name: Elo hráče, dtype: int64
# Unique values: 18827
#
# ------------------------------
# Column: Elo (min)
# 1-> 1          162
# 1215-> 1215     28
# 1272-> 1272     27
# 1196-> 1196     25
# 1174-> 1174     24
# Name: Elo (min), dtype: int64
# Unique values: 18912
#
# ------------------------------
# Column: Elo (max)
# 1273-> 1273    29
# 1397-> 1397    26
# 1381-> 1381    25
# 1227-> 1227    25
# 1331-> 1331    24
# Name: Elo (max), dtype: int64
# Unique values: 18962
#
# ------------------------------
# Column: Elo soupeře
# 1-> 1          358
# 1263-> 1263     24
# 1237-> 1237     24
# 1120-> 1120     23
# 1170-> 1170     22
# Name: Elo soupeře, dtype: int64
# Unique values: 18910
#
# ------------------------------
# Column: Elo (min) soupeře
# 1-> 1          365
# 1134-> 1134     26
# 1141-> 1141     25
# 1237-> 1237     25
# 1165-> 1165     24
# Name: Elo (min) soupeře, dtype: int64
# Unique values: 19008
#
# ------------------------------
# Column: Elo (max) soupeře
# 1178-> 1178    23
# 1253-> 1253    23
# 1245-> 1245    23
# 1269-> 1269    22
# 1243-> 1243    22
# Name: Elo (max) soupeře, dtype: int64
# Unique values: 19214
#
# ------------------------------
# Column: Rok narození
# 1973    1789
# 1972    1685
# 1975    1666
# 1974    1642
# 1970    1545
# Name: Rok narození, dtype: int64
# Unique values: 79
#
# ------------------------------
# Column: Max elo
# ------------------------------
# Column: Elo nejlepšího poraženého soupeře
# ------------------------------
# Column: ID Hráč
# /st/hrac/radil_milan_1951            26
# /st/hrac/blecha_pavel_1964           21
# /st/hrac/richter_jaroslav_ml_1973    21
# /st/hrac/stefanides_petr_1966        21
# /st/hrac/muron_david_1970            20
# Name: ID Hráč, dtype: int64
# Unique values: 12798
#
# ------------------------------
# Column: ID Soupeř
# urban_martin_1976       15
# frehar_jiri_1949        15
# kanclir_premysl_1983    15
# skopkova_vera_1994      14
# tichy_jiri_1986         14
# Name: ID Soupeř, dtype: int64
# Unique values: 19808
#
# ------------------------------
# Column: Rok narození soupeř
# 1973    1738
# 1975    1524
# 1972    1511
# 1964    1450
# 1970    1428
# Name: Rok narození soupeř, dtype: int64
# Unique values: 87

# %% [markdown]
# # Histograms

# %%
for c in num_c:
    plt.hist(df[c])
    plt.title(c)
    plt.show()

# %% [markdown]
# # Correlation

# %%
try:
    fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
    sns.heatmap(df[num_c].corr())
except:
    pass
