# %%
import os

import pandas as pd
from pyspark.ml.feature import Imputer, StandardScaler, VectorAssembler
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import BooleanType, IntegerType

# %%
label_name = 'Hráč vyhrál'

# %%
spark = SparkSession.builder.appName("elo_app").getOrCreate()
# Out:
# 21/12/22 18:23:36 WARN Utils: Your hostname, macusers-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.0.131 instead (on interface en0)
# 21/12/22 18:23:36 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/12/22 18:23:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 21/12/22 18:23:37 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# # Load main data

# %%
df = spark.read.csv('data/2_raw_unioned.csv.gz', header=True)
df.limit(5).toPandas()
# Out:
#             Hráč             Oddíl          Družstvo            Soupeř  \
# 0  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod    Tomáš Martinko
# 1  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod       Patrik Klos
# 2  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod   David Reitšpies
# 3  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod  Stanislav Kučera
# 4  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod   Martin Koblížek
#
#                     Oddíl soupeř Družstvo soupeř Výsledek Datum zápasu  \
# 0   Tělovýchovná jednota Ostrava  TJ Ostrava KST      0:3   26.11.2021
# 1   Tělovýchovná jednota Ostrava  TJ Ostrava KST      3:1   26.11.2021
# 2                      SKST Cheb       SKST Cheb      1:3   11.11.2021
# 3                      SKST Cheb       SKST Cheb      3:0   11.11.2021
# 4  Klub stolního tenisu KT Praha        KT Praha      3:0    5.11.2021
#
#            Soutěž    Elo hráče  ...    Elo (max)  Elo soupeře  \
# 0  Extraliga mužů  2454-> 2444  ...  2482-> 2470  2306-> 2318
# 1  Extraliga mužů  2452-> 2454  ...  2480-> 2482  2317-> 2315
# 2  Extraliga mužů  2458-> 2452  ...  2485-> 2479  2409-> 2419
# 3  Extraliga mužů  2454-> 2458  ...  2482-> 2485  2380-> 2377
# 4  Extraliga mužů  2453-> 2454  ...  2482-> 2482  2241-> 2241
#
#   Elo (min) soupeře Elo (max) soupeře Rok narození Max elo  \
# 0       2289-> 2301       2327-> 2338         1990    2458
# 1       2300-> 2299       2343-> 2341         1990    2458
# 2       2356-> 2380       2476-> 2484         1990    2458
# 3       2339-> 2337       2407-> 2403         1990    2458
# 4       2215-> 2215       2264-> 2263         1990    2458
#
#   Elo nejlepšího poraženého soupeře                      ID Hráč  \
# 0                              2446  /st/hrac/tregler_tomas_1990
# 1                              2446  /st/hrac/tregler_tomas_1990
# 2                              2446  /st/hrac/tregler_tomas_1990
# 3                              2446  /st/hrac/tregler_tomas_1990
# 4                              2446  /st/hrac/tregler_tomas_1990
#
#                ID Soupeř Rok narození soupeř
# 0    martinko_tomas_2002                2002
# 1       klos_patrik_1998                1998
# 2   reitspies_david_1996                1996
# 3  kucera_stanislav_1997                1997
# 4   koblizek_martin_1996                1996
#
# [5 rows x 21 columns]

# %% [markdown]
# # Get players information only

# %%
players = (df
    .select(["ID hráč", "Max elo", "Elo nejlepšího poraženého soupeře"])
    .withColumn("ID hráč", F.substring(F.col("ID Hráč"), 10, 70))
    .distinct()
    .rdd.toDF(["ID hráč_soupeř", "Max elo_soupeř", "Elo nejlepšího poraženého soupeře_soupeř"])
)
players.limit(5).toPandas()
# Out:
#        ID hráč_soupeř Max elo_soupeř Elo nejlepšího poraženého soupeře_soupeř
# 0    zaboj_matej_2002           1893                                     2034
# 1  spacek_zbynek_1959           1917                                     2065
# 2    mokrejs_jan_2002           2110                                     2262
# 3   sikora_filip_1997           2022                                     2174
# 4   splichal_jan_1979           1899                                     1973

# %% [markdown]
# # Add players (opponents) information to the original games dataset

# %%
df_joined = df.join(players, on=(df['ID Soupeř'] == players['ID Hráč_soupeř']), how='left')
df_joined.limit(5).toPandas()
# Out:
#             Hráč             Oddíl          Družstvo            Soupeř  \
# 0  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod  Stanislav Kučera
# 1  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod   Martin Koblížek
# 2  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod   David Reitšpies
# 3  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod       Patrik Klos
# 4  Tomáš Tregler  HB Ostrov , z.s.  HB Ostrov H.Brod    Tomáš Martinko
#
#                     Oddíl soupeř Družstvo soupeř Výsledek Datum zápasu  \
# 0                      SKST Cheb       SKST Cheb      3:0   11.11.2021
# 1  Klub stolního tenisu KT Praha        KT Praha      3:0    5.11.2021
# 2                      SKST Cheb       SKST Cheb      1:3   11.11.2021
# 3   Tělovýchovná jednota Ostrava  TJ Ostrava KST      3:1   26.11.2021
# 4   Tělovýchovná jednota Ostrava  TJ Ostrava KST      0:3   26.11.2021
#
#            Soutěž    Elo hráče  ... Elo (max) soupeře Rok narození Max elo  \
# 0  Extraliga mužů  2454-> 2458  ...       2407-> 2403         1990    2458
# 1  Extraliga mužů  2453-> 2454  ...       2264-> 2263         1990    2458
# 2  Extraliga mužů  2458-> 2452  ...       2476-> 2484         1990    2458
# 3  Extraliga mužů  2452-> 2454  ...       2343-> 2341         1990    2458
# 4  Extraliga mužů  2454-> 2444  ...       2327-> 2338         1990    2458
#
#   Elo nejlepšího poraženého soupeře                      ID Hráč  \
# 0                              2446  /st/hrac/tregler_tomas_1990
# 1                              2446  /st/hrac/tregler_tomas_1990
# 2                              2446  /st/hrac/tregler_tomas_1990
# 3                              2446  /st/hrac/tregler_tomas_1990
# 4                              2446  /st/hrac/tregler_tomas_1990
#
#                ID Soupeř Rok narození soupeř         ID hráč_soupeř  \
# 0  kucera_stanislav_1997                1997  kucera_stanislav_1997
# 1   koblizek_martin_1996                1996   koblizek_martin_1996
# 2   reitspies_david_1996                1996   reitspies_david_1996
# 3       klos_patrik_1998                1998       klos_patrik_1998
# 4    martinko_tomas_2002                2002    martinko_tomas_2002
#
#   Max elo_soupeř Elo nejlepšího poraženého soupeře_soupeř
# 0           2404                                     2425
# 1           2264                                     2339
# 2           2419                                     2458
# 3           2324                                     2419
# 4           2327                                     2454
#
# [5 rows x 24 columns]

# %% [markdown]
# # Create new features

# %%
def get_season(dt):
    if dt >= 3 and dt <= 5:
        return 1
    if dt >= 6 and dt <= 8:
        return 2
    if dt >= 9 and dt <= 11:
        return 3
    return 4

# create pyspark UDF
udf_get_season = F.udf(get_season, IntegerType())

# %%
# apply transformations
result_df = (df_joined
    .withColumn("Datum zápasu", F.to_date(F.col("Datum zápasu"), 'd.m.yyyy'))   # convert to date
    .withColumn("obdobi", udf_get_season(F.month("Datum zápasu")))              # get year season
    .withColumn("Den v týdnu", F.dayofweek(F.col("Datum zápasu")) - 1)
    .withColumn("Víkend", F.col("Den v týdnu") > 6)
    .withColumn("Hráč sety", F.substring("Výsledek", 0, 1))                     # get players sets
    .withColumn("Soupeř sety", F.substring("Výsledek", -1, 1))                  # get opponents sets
    .withColumn("Hráč vyhrál", F.col("Hráč sety") > F.col("Soupeř sety"))
    .withColumn("Elo hráče před", F.split(F.col("Elo hráče"), '->').getItem(0))
    .withColumn("Elo soupeře před", F.split(F.col("Elo soupeře"), '->').getItem(1))
    .withColumn("Hráč je žena", F.col("Hráč").rlike(".*ová$"))
    .withColumn("Soupeř je žena", F.col("Soupeř").rlike(".*ová$"))
    .select(['Rok narození', 'Elo hráče před', 'Hráč je žena', 'Max elo', 'Elo nejlepšího poraženého soupeře',
        'Rok narození soupeř', 'Elo soupeře před', 'Soupeř je žena', 'Max elo_soupeř', 'Elo nejlepšího poraženého soupeře_soupeř',
        'Den v týdnu', 'Víkend', 'obdobi', 'Hráč vyhrál'])
)
result_df = result_df.select(*(F.col(c).cast("double").alias(c) for c in result_df.columns))
result_df.limit(5).toPandas()
# Out:
#    Rok narození  Elo hráče před  Hráč je žena  Max elo  \
# 0        1990.0          2454.0           0.0   2458.0
# 1        1990.0          2453.0           0.0   2458.0
# 2        1990.0          2458.0           0.0   2458.0
# 3        1990.0          2452.0           0.0   2458.0
# 4        1990.0          2454.0           0.0   2458.0
#
#    Elo nejlepšího poraženého soupeře  Rok narození soupeř  Elo soupeře před  \
# 0                             2446.0               1997.0            2377.0
# 1                             2446.0               1996.0            2241.0
# 2                             2446.0               1996.0            2419.0
# 3                             2446.0               1998.0            2315.0
# 4                             2446.0               2002.0            2318.0
#
#    Soupeř je žena  Max elo_soupeř  Elo nejlepšího poraženého soupeře_soupeř  \
# 0             0.0          2404.0                                    2425.0
# 1             0.0          2264.0                                    2339.0
# 2             0.0          2419.0                                    2458.0
# 3             0.0          2324.0                                    2419.0
# 4             0.0          2327.0                                    2454.0
#
#    Den v týdnu  Víkend  obdobi  Hráč vyhrál
# 0          1.0     0.0     4.0          1.0
# 1          2.0     0.0     4.0          1.0
# 2          1.0     0.0     4.0          0.0
# 3          2.0     0.0     4.0          1.0
# 4          2.0     0.0     4.0          0.0

# %%
result_df.select('Hráč vyhrál').groupby('Hráč vyhrál').count().toPandas()
# Out:
#    Hráč vyhrál    count
# 0          0.0  2827534
# 1          1.0  3103891

# %% [markdown]
# Our label is pretty well balanced

# %%
result_df.describe().toPandas()
# Out:
#   summary        Rok narození      Elo hráče před         Hráč je žena  \
# 0   count             5931425             5931425              5931425
# 1    mean   1974.988180917739  1358.7082235719072  0.04290537265496908
# 2  stddev  18.809642545545348  262.46993198730803   0.2026437972786701
# 3     min              1073.0                 1.0                  0.0
# 4     max              2015.0              2458.0                  1.0
#
#               Max elo Elo nejlepšího poraženého soupeře Rok narození soupeř  \
# 0             5928143                           5928219             5931425
# 1  1461.2486998036316                 1610.121636869353  1975.2562772015156
# 2  251.34465835442762                227.68702035001098  18.717733731702715
# 3               101.0                             144.0              1073.0
# 4              2458.0                            2458.0              2015.0
#
#     Elo soupeře před        Soupeř je žena      Max elo_soupeř  \
# 0            5931425               5931425             4248382
# 1  1343.436152189398  0.047108578461330965  1472.6605385297273
# 2   282.033296310156    0.2118711114445313  251.55849379730608
# 3                1.0                   0.0               101.0
# 4             2458.0                   1.0              2458.0
#
#   Elo nejlepšího poraženého soupeře_soupeř         Den v týdnu   Víkend  \
# 0                                  4248470             5931425  5931425
# 1                        1619.898580900889  3.0331862916584127      0.0
# 2                       228.21478972334734  1.9645722023332164      0.0
# 3                                    144.0                 0.0      0.0
# 4                                   2458.0                 6.0      0.0
#
#     obdobi          Hráč vyhrál
# 0  5931425              5931425
# 1      4.0   0.5232960039113703
# 2      0.0  0.49945704345684866
# 3      4.0                  0.0
# 4      4.0                  1.0

# %% [markdown]
# Some values are missing.. Not a small number - lets impute them

# %% [markdown]
# # Impute

# %%
imp = Imputer(
    strategy='median', 
    inputCols=["Max elo", "Elo nejlepšího poraženého soupeře", "Max elo_soupeř", "Elo nejlepšího poraženého soupeře_soupeř"],
    outputCols=["Max elo", "Elo nejlepšího poraženého soupeře", "Max elo_soupeř", "Elo nejlepšího poraženého soupeře_soupeř"]
)
imp_model = imp.fit(result_df)
df_imputed = imp_model.transform(result_df)
df_imputed.limit(5).toPandas()
# Out:
#    Rok narození  Elo hráče před  Hráč je žena  Max elo  \
# 0        1990.0          2454.0           0.0   2458.0
# 1        1990.0          2453.0           0.0   2458.0
# 2        1990.0          2458.0           0.0   2458.0
# 3        1990.0          2452.0           0.0   2458.0
# 4        1990.0          2454.0           0.0   2458.0
#
#    Elo nejlepšího poraženého soupeře  Rok narození soupeř  Elo soupeře před  \
# 0                             2446.0               1997.0            2377.0
# 1                             2446.0               1996.0            2241.0
# 2                             2446.0               1996.0            2419.0
# 3                             2446.0               1998.0            2315.0
# 4                             2446.0               2002.0            2318.0
#
#    Soupeř je žena  Max elo_soupeř  Elo nejlepšího poraženého soupeře_soupeř  \
# 0             0.0          2404.0                                    2425.0
# 1             0.0          2264.0                                    2339.0
# 2             0.0          2419.0                                    2458.0
# 3             0.0          2324.0                                    2419.0
# 4             0.0          2327.0                                    2454.0
#
#    Den v týdnu  Víkend  obdobi  Hráč vyhrál
# 0          1.0     0.0     4.0          1.0
# 1          2.0     0.0     4.0          1.0
# 2          1.0     0.0     4.0          0.0
# 3          2.0     0.0     4.0          1.0
# 4          2.0     0.0     4.0          0.0

# %%
# make sure we imputed missing values correctly
df_imputed.filter(F.col("Max elo").isNull()).limit(5).toPandas()
# Out:
# [Stage 65:===================================================>    (12 + 1) / 13]
# Empty DataFrame
# Columns: [Rok narození, Elo hráče před, Hráč je žena, Max elo, Elo nejlepšího poraženého soupeře, Rok narození soupeř, Elo soupeře před, Soupeř je žena, Max elo_soupeř, Elo nejlepšího poraženého soupeře_soupeř, Den v týdnu, Víkend, obdobi, Hráč vyhrál]
# Index: []

# %% [markdown]
# # Scale

# %%
feature_cols = df_imputed.drop('Hráč vyhrál').columns

# %%
# create vector
assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol='features'
)
df_vector = assembler.transform(df_imputed)

# scale
ss = StandardScaler(inputCol='features', outputCol='features_scaled')
scaler_model = ss.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

df_scaled.limit(5).toPandas()
# Out:
# 21/12/22 18:25:37 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Traceback (most recent call last):
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/worker.py", line 663, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#    Rok narození  Elo hráče před  Hráč je žena  Max elo  \
# 0        2002.0          1775.0           0.0   2327.0
# 1        2002.0          1729.0           0.0   2327.0
# 2        1998.0          1917.0           0.0   2324.0
# 3        2002.0          2088.0           0.0   2263.0
# 4        2002.0          1680.0           0.0   2263.0
#
#    Elo nejlepšího poraženého soupeře  Rok narození soupeř  Elo soupeře před  \
# 0                             2454.0               1996.0            1689.0
# 1                             2454.0               1985.0            1690.0
# 2                             2419.0               1987.0            1955.0
# 3                             2334.0               1989.0            1963.0
# 4                             2334.0               1981.0            1653.0
#
#    Soupeř je žena  Max elo_soupeř  Elo nejlepšího poraženého soupeře_soupeř  \
# 0             0.0          1739.0                                    1920.0
# 1             0.0          1760.0                                    1927.0
# 2             0.0          1981.0                                    2083.0
# 3             0.0          1477.0                                    1622.0
# 4             0.0          1477.0                                    1622.0
#
#    Den v týdnu  Víkend  obdobi  Hráč vyhrál  \
# 0          4.0     0.0     4.0          1.0
# 1          4.0     0.0     4.0          1.0
# 2          0.0     0.0     4.0          0.0
# 3          3.0     0.0     4.0          1.0
# 4          3.0     0.0     4.0          1.0
#
#                                             features  \
# 0  [2002.0, 1775.0, 0.0, 2327.0, 2454.0, 1996.0, ...
# 1  [2002.0, 1729.0, 0.0, 2327.0, 2454.0, 1985.0, ...
# 2  [1998.0, 1917.0, 0.0, 2324.0, 2419.0, 1987.0, ...
# 3  [2002.0, 2088.0, 0.0, 2263.0, 2334.0, 1989.0, ...
# 4  [2002.0, 1680.0, 0.0, 2263.0, 2334.0, 1981.0, ...
#
#                                      features_scaled
# 0  [106.43477116337492, 6.762679391732501, 0.0, 9...
# 1  [106.43477116337492, 6.58742122158056, 0.0, 9....
# 2  [106.22211427793361, 7.303693743071101, 0.0, 9...
# 3  [106.43477116337492, 7.955196940809838, 0.0, 9...
# 4  [106.43477116337492, 6.400733170766536, 0.0, 9...

# %% [markdown]
# # Output

# %%
df_final = (df_scaled
    .select(['features_scaled', 'Hráč vyhrál'])
    .withColumnRenamed('Hráč vyhrál', 'label')
    .withColumnRenamed('features_scaled', 'features')
)
df_final.write.mode('overwrite').parquet('data/4_processed')
with open('data/feature_list.txt', 'w') as f:
    for fe in feature_cols:
        f.write(f"{fe}\n")

df_final.limit(5).toPandas()
# Out:
# 21/12/22 18:26:47 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
#                                             features  label
# 0  [106.43477116337492, 6.762679391732501, 0.0, 9...    1.0
# 1  [106.43477116337492, 6.58742122158056, 0.0, 9....    1.0
# 2  [106.22211427793361, 7.303693743071101, 0.0, 9...    0.0
# 3  [106.43477116337492, 7.955196940809838, 0.0, 9...    1.0
# 4  [106.43477116337492, 6.400733170766536, 0.0, 9...    1.0
# Traceback (most recent call last):
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/worker.py", line 663, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/Users/romanzdk/Repos/-VSE-Applied_ML/venv/lib/python3.10/site-packages/pyspark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
